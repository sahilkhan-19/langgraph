# %%
from dotenv import load_dotenv
from langgraph.graph import StateGraph, START, END
from typing import TypedDict
from langchain_groq import ChatGroq

# %%
load_dotenv()  # Load environment variables from .env file

model = ChatGroq(
    model = "llama-3.3-70b-versatile"
)

# %%
class BlogState(TypedDict):
    title: str
    outline: str
    content: str

# %%
def create_outline(state: BlogState) -> BlogState:
    # fetch title from state
    title = state['title']

    # call llm & generate outline
    prompt = f"Create an outline for a blog post with the title: {title}"
    outline = model.invoke(prompt).content

    # update state
    state['outline'] = outline
    return state

# %%
def create_blog(state: BlogState) -> BlogState:

    title = state['title']
    outline = state['outline']
    prompt = f"Create a detailed blog post with the title: {title} and the following outline: {outline}"

    content = model.invoke(prompt).content
    state['content'] = content
    return state

# %%
graph = StateGraph(BlogState)

graph.add_node('create_outline', create_outline)
graph.add_node('create_blog', create_blog)

graph.add_edge(START, 'create_outline')
graph.add_edge('create_outline', 'create_blog')
graph.add_edge('create_blog', END)

workflow = graph.compile()

initial_state = {'title': 'Black Hole'}
final_state = workflow.invoke(initial_state)
print(final_state['content'])
# Out:
# **Black Hole**
#
# The universe has always been a source of fascination and mystery for humanity. Among the many wonders that it holds, black holes are perhaps the most intriguing and complex regions of space. These enigmatic entities have captivated the imagination of scientists and the general public alike, and their importance in our understanding of the universe cannot be overstated. In this blog post, we will delve into the world of black holes, exploring what they are, how they are formed, and their fascinating properties. Black holes are fascinating and complex regions of space that continue to capture the imagination of scientists and the general public alike.
#
# ## **I. Introduction**
#
# A black hole is essentially a region of space where the gravitational pull is so strong that nothing, including light, can escape. This is due to the massive amount of matter that is packed into an incredibly small space, creating an intense gravitational field. The importance of black holes lies in their ability to help us understand the fundamental laws of physics, particularly gravity and quantum mechanics. By studying black holes, scientists can gain insights into the behavior of matter and energy under extreme conditions, which can shed light on the workings of the universe as a whole.
#
# ## **II. What is a Black Hole?**
#
# So, what exactly is a black hole? A black hole is formed when a massive star collapses in on itself, causing a massive amount of matter to be compressed into an incredibly small space. This compression creates an intense gravitational field, which warps the fabric of space and time around the black hole. The point of no return, called the event horizon, marks the boundary beyond which anything that enters cannot escape. At the center of the black hole lies the singularity, a point of infinite density and zero volume, where the laws of physics as we know them break down.
#
# The key characteristics of a black hole include its event horizon, singularity, and gravitational pull. The event horizon is the point of no return, while the singularity is the point of infinite density and zero volume. The gravitational pull of a black hole is so strong that it warps the fabric of space and time around it, causing any nearby matter or radiation to be pulled towards the singularity.
#
# ## **III. Types of Black Holes**
#
# There are several types of black holes, each with its unique characteristics. Stellar black holes are the smallest and most common type, formed from the collapse of individual stars. Supermassive black holes, on the other hand, are found at the centers of galaxies and can have masses millions or even billions of times that of the sun. Intermediate-mass black holes, as the name suggests, fall somewhere in between these two categories.
#
# Each type of black hole has its own unique characteristics. Stellar black holes are typically small and have relatively weak gravitational fields, while supermassive black holes have incredibly strong gravitational fields that can affect the entire galaxy. Intermediate-mass black holes, meanwhile, can have a significant impact on the surrounding space, but are not as massive as supermassive black holes.
#
# ## **IV. Properties of Black Holes**
#
# One of the most fascinating properties of black holes is their gravitational pull. The gravity of a black hole is so strong that it warps the fabric of space and time around it, causing any nearby matter or radiation to be pulled towards the singularity. This warping of space-time also causes the bending of light, a phenomenon known as gravitational lensing.
#
# The effects of a black hole on the surrounding space-time are also of great interest. The strong gravity of a black hole can cause the formation of accretion disks, which are disks of hot, dense gas that swirl around the black hole. These accretion disks can emit intense radiation, including X-rays and gamma rays, which can be detected by telescopes.
#
# Despite the many advances that have been made in our understanding of black holes, there is still much that is not known. The information paradox, which questions what happens to the information contained in matter that falls into a black hole, remains one of the greatest unsolved puzzles in physics. Hawking radiation, which is the theoretical prediction that black holes emit radiation due to quantum effects, is another area of ongoing research and debate.
#
# ## **V. Detection and Observation of Black Holes**
#
# Detecting black holes is a challenging task, as they do not emit any light or radiation. Instead, scientists rely on indirect detection methods, such as observing the effects of a black hole on the surrounding space-time. X-ray and gamma ray observations can reveal the presence of hot, dense gas swirling around a black hole, while gravitational wave detection can reveal the merger of two black holes.
#
# Some notable black hole discoveries include Cygnus X-1, which was the first black hole to be discovered, and M87*, which is a supermassive black hole located at the center of the galaxy Messier 87. The detection of these black holes has provided valuable insights into the properties of black holes and the behavior of matter and energy under extreme conditions.
#
# ## **VI. Conclusion**
#
# In conclusion, black holes are fascinating and complex regions of space that continue to capture the imagination of scientists and the general public alike. By studying black holes, we can gain insights into the fundamental laws of physics, particularly gravity and quantum mechanics. The different types of black holes, including stellar, supermassive, and intermediate-mass black holes, each have their unique characteristics and properties.
#
# The detection and observation of black holes are ongoing areas of research, with scientists using a variety of indirect detection methods to study these enigmatic entities. Despite the many advances that have been made, there is still much that is not known about black holes, and ongoing research and exploration are needed to fully understand these complex regions of space.
#
# As we continue to explore and study black holes, we may uncover new and exciting secrets about the universe and its many mysteries. The study of black holes is an active and dynamic field, with new discoveries and advances being made regularly. As we look to the future, it is clear that black holes will remain a fascinating and important area of research, with the potential to reveal new insights into the workings of the universe.
